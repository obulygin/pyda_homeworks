# %% [markdown]
# # Домашнее задание
# 1. Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# ```python
# {'1840e0b9d4': 'Продукты', ...}
# ```
#
# 2. Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки (если покупка была, сам файл visit_log.csv изменять не надо). Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были покупки с указанием категории.
#
# Учтите условия на данные:
# - содержимое purchase_log.txt помещается в оперативную память компьютера
# - содержимое visit_log.csv - нет; используйте только построчную обработку этого файла

# %%
import json
purchases = dict()

with open('purchase_log.txt', 'r') as p_log:
    i = p_log.readline()
    for i in p_log.readlines():
        i_dict = json.loads(i)
        purchases[i_dict['user_id']] = i_dict['category']
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
purchases
# Out:
# {'1840e0b9d4': 'Продукты',
#  '4e4f90fcfb': 'Электроника',
#  'afea8d72fc': 'Электроника',
#  '373a6055fe': 'Бытовая техника',
#  '9b2ab046f3': 'Электроника',
#  '9f39d307c3': 'Электроника',
#  '44edeffc91': 'Продукты',
#  '704474fa2d': 'Продукты',
#  '1de31be403': 'Бытовая техника',
#  'b71f36a5e4': 'Продукты',
#  '79843a685a': 'Продукты',
#  'ff68cee0d6': 'Бытовая техника',
#  'e8447c40e2': 'Досуг',
#  '98d290be27': 'Электроника',
#  'fa0079a5a8': 'Досуг',
#  '22d2f03a17': 'Досуг',
#  '3f8e1ccd3f': 'Электроника',
#  '81a9988b83': 'Электроника',
#  '65f44a2eb7': 'Досуг',
#  '5f8fbb0149': 'Бытовая техника',
#  '3ecff691fd': 'Электроника',
#  'dd0e912251': 'Электроника',
#  '9250593d55': 'Электроника',
#  '37c4e090e4': 'Электроника',
#  '22fa3ea76f': 'Электроника',
#  '73b876b237': 'Электроника',
#  'f983a69d67': 'Товары для животных',
#  '4ea17212f8': 'Продукты',
#  'c6de96a5e2': 'Товары для животных',
#  'd8e3bcee53': 'Продукты',
#  '680aa815f9': 'Продукты',
# ...

# %%
import csv
with open('purchase_log.txt', 'r') as p_log, \
     open('visit_log.csv', 'r') as v_log, \
     open('funnel.csv', 'w') as f_log:
    visit_reader = csv.reader(v_log, delimiter=',')
    funnel_writer = csv.writer(f_log, delimiter=',')
    next(visit_reader)
    for row in visit_reader:
        if row[0] in purchases.keys():
            funnel_writer.writerow(row)

# %%
with open('funnel.csv', 'r') as f:
    print(f.readlines())
# Out:
# ['1840e0b9d4,other\n', '4e4f90fcfb,context\n', 'afea8d72fc,other\n', '2824221f38,email\n', '373a6055fe,other\n', '9b2ab046f3,other\n', '9f39d307c3,context\n', '44edeffc91,context\n', '704474fa2d,other\n', '1de31be403,other\n', '5da0dedf13,context\n', 'b71f36a5e4,other\n', '79843a685a,context\n', 'ff68cee0d6,context\n', 'e8447c40e2,email\n', 'b9ef8fdf47,other\n', '98d290be27,other\n', '3fff459bda,other\n', 'fa0079a5a8,other\n', 'fdd6b2fc76,context\n', '54ecd881a2,other\n', '22d2f03a17,context\n', 'c9fa1b54d5,other\n', '3f8e1ccd3f,other\n', '81a9988b83,context\n', '65f44a2eb7,context\n', '6df948569b,other\n', '5f8fbb0149,other\n', '3ecff691fd,context\n', 'dd0e912251,other\n', '9250593d55,other\n', '37c4e090e4,other\n', '22fa3ea76f,other\n', '73b876b237,context\n', 'ed6b87f95d,context\n', 'f983a69d67,other\n', '4ea17212f8,other\n', 'c6de96a5e2,other\n', '4175fd2e58,other\n', 'd8e3bcee53,context\n', '680aa815f9,other\n', '4a92a68cf9,other\n', '905e60cb52,other\n', '393bcfb298,other\n', '
# ...
